# %%
import pandas as pd                                     #Required libraries
import pm4py
from pm4py.objects.conversion.log import converter as xes_converter
from pm4py.objects.log.importer.xes import importer as xes_importer
from pm4py.objects.conversion.log import converter as log_converter
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
log = pm4py.read_xes('BPIC15_5.xes')          #Converting xes data to csv.
dataframe = log_converter.apply(log, variant=log_converter.Variants.TO_DATA_FRAME)
dataframe.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='parsing log, completed traces :: ', max=1156.0, style=Pro…
#   question         dateFinished                    dueDate   action_code  \
# 0    EMPTY  2014-01-10 00:00:00  2014-01-15 08:45:53+01:00  01_HOOFD_010
# 1    False  2014-01-10 00:00:00                        NaN  01_HOOFD_011
# 2     True  2014-01-10 00:00:00                        NaN  01_HOOFD_020
# 3     True  2014-01-10 00:00:00                        NaN    03_GBH_005
# 4    False  2014-01-10 00:00:00                        NaN   05_EIND_010
#
#                      activityNameEN                    planned  \
# 0  register submission date request  2014-01-13 08:45:53+01:00
# 1              OLO messaging active  2014-01-13 08:55:48+01:00
# 2         send confirmation receipt  2014-01-13 08:55:49+01:00
# 3          applicant is stakeholder  2014-01-13 08:55:49+01:00
# 4              terminate on request  2014-01-13 08:55:49+01:00
#
#               time:timestamp monitoringResource org:resource  \
# 0  2014-01-06 00:00:00+01:00            8492512      8492512
# 1  2014-01-10 00:00:00+01:00             560604      8492512
# 2  2014-01-10 00:00:00+01:00             560604      8492512
# 3  2014-01-10 00:00:00+01:00             560604      8492512
# 4  2014-01-10 00:00:00+01:00             560604      8492512
#
#                            activityNameNL  ... case:landRegisterID case:parts  \
# 0  registratie datum binnenkomst aanvraag  ...             6966675       Bouw
# 1             OLO berichtenverkeer actief  ...             6966675       Bouw
# 2          versturen ontvangstbevestiging  ...             6966675       Bouw
# 3             aanvrager is belanghebbende  ...             6966675       Bouw
# 4                   beeindigen op verzoek  ...             6966675       Bouw
#
#                  case:termName             case:startDate  \
# 0  Termijn bezwaar en beroep 1  2014-01-06 00:00:00+01:00
# 1  Termijn bezwaar en beroep 1  2014-01-06 00:00:00+01:00
# 2  Termijn bezwaar en beroep 1  2014-01-06 00:00:00+01:00
# 3  Termijn bezwaar en beroep 1  2014-01-06 00:00:00+01:00
# 4  Termijn bezwaar en beroep 1  2014-01-06 00:00:00+01:00
#
#    case:requestComplete case:IDofConceptCase case:caseProcedure  \
# 0                  TRUE             10061287                NaN
# 1                  TRUE             10061287                NaN
# 2                  TRUE             10061287                NaN
# 3                  TRUE             10061287                NaN
# 4                  TRUE             10061287                NaN
#
#   case:Includes_subCases case:endDatePlanned dateStop
# 0                    NaN                 NaN      NaN
# 1                    NaN                 NaN      NaN
# 2                    NaN                 NaN      NaN
# 3                    NaN                 NaN      NaN
# 4                    NaN                 NaN      NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # 1. Data Analysis

# %%
dataframe.columns           #total columns
# Out:
# Index(['question', 'dateFinished', 'dueDate', 'action_code', 'activityNameEN',
#        'planned', 'time:timestamp', 'monitoringResource', 'org:resource',
#        'activityNameNL', 'concept:name', 'lifecycle:transition',
#        'case:endDate', 'case:caseStatus', 'case:SUMleges', 'case:last_phase',
#        'case:case_type', 'case:concept:name', 'case:Responsible_actor',
#        'case:landRegisterID', 'case:parts', 'case:termName', 'case:startDate',
#        'case:requestComplete', 'case:IDofConceptCase', 'case:caseProcedure',
#        'case:Includes_subCases', 'case:endDatePlanned', 'dateStop'],
#       dtype='object')

# %%
unique=[]
clmn=['Unique value']
for col in dataframe:
    unique.append(len(dataframe[col].unique()))
    
unique= pd.DataFrame(unique, index= dataframe.columns, columns=clmn)       #No of unique values of each column
unique
# Out:
#                         Unique value
# question                         625
# dateFinished                    5683
# dueDate                         2868
# action_code                      386
# activityNameEN                   285
# planned                        34437
# time:timestamp                 21021
# monitoringResource                16
# org:resource                      22
# activityNameNL                   285
# concept:name                     389
# lifecycle:transition               1
# case:endDate                     727
# case:caseStatus                    3
# case:SUMleges                    566
# case:last_phase                   25
# case:case_type                     1
# case:concept:name               1156
# case:Responsible_actor             8
# case:landRegisterID              857
# case:parts                       107
# case:termName                     11
# case:startDate                   754
# case:requestComplete               2
# case:IDofConceptCase             638
# case:caseProcedure                 3
# case:Includes_subCases             3
# case:endDatePlanned                4
# dateStop                           2

# %% [markdown]
# ### 1.1 Null values

# %%
dataframe.isnull().sum()                   #NO of null values in each column
# Out:
# question                      0
# dateFinished                  0
# dueDate                   56215
# action_code                  57
# activityNameEN                0
# planned                    9782
# time:timestamp                0
# monitoringResource            0
# org:resource                  0
# activityNameNL                0
# concept:name                  0
# lifecycle:transition          0
# case:endDate               2130
# case:caseStatus               0
# case:SUMleges              8409
# case:last_phase               0
# case:case_type                0
# case:concept:name             0
# case:Responsible_actor        0
# case:landRegisterID        1252
# case:parts                  136
# case:termName             46410
# case:startDate                0
# case:requestComplete          0
# case:IDofConceptCase      26240
# case:caseProcedure        52791
# case:Includes_subCases    15027
# case:endDatePlanned       58931
# dateStop                  59081
# dtype: int64

# %%
dataframe['case:caseStatus'].unique()
# Out:
# array(['G', 'O', 'T'], dtype=object)

# %%
Tcase=dataframe[dataframe['case:caseStatus']== "T"]
closedCase= dataframe[dataframe['case:caseStatus']=="G"]
openCase= dataframe[dataframe['case:caseStatus']=="O"]

# %%
closedCase.shape            #considering only closed cases.
# Out:
# (54562, 29)

# %%
#Removing unneccessary columns.

dfAfterDrop= closedCase.drop(['question','dueDate', 'case:termName', 'case:IDofConceptCase', 'case:caseProcedure',
                             'case:Includes_subCases','case:endDatePlanned','dateStop',
                            'dateFinished','planned','monitoringResource',
                              'org:resource','activityNameNL','concept:name','lifecycle:transition',
                             'case:caseStatus','case:SUMleges','case:case_type','case:Responsible_actor',
                             'case:landRegisterID','case:parts'], axis=1)

# %%
dfAfterDrop.shape       #Data remins after droping unneccessary columns.
# Out:
# (54562, 8)

# %%
dfAfterDrop.head()
# Out:
#     action_code                    activityNameEN             time:timestamp  \
# 0  01_HOOFD_010  register submission date request  2014-01-06 00:00:00+01:00
# 1  01_HOOFD_011              OLO messaging active  2014-01-10 00:00:00+01:00
# 2  01_HOOFD_020         send confirmation receipt  2014-01-10 00:00:00+01:00
# 3    03_GBH_005          applicant is stakeholder  2014-01-10 00:00:00+01:00
# 4   05_EIND_010              terminate on request  2014-01-10 00:00:00+01:00
#
#                 case:endDate         case:last_phase case:concept:name  \
# 0  2014-02-24 00:00:00+01:00  Besluit onherroepelijk          10061280
# 1  2014-02-24 00:00:00+01:00  Besluit onherroepelijk          10061280
# 2  2014-02-24 00:00:00+01:00  Besluit onherroepelijk          10061280
# 3  2014-02-24 00:00:00+01:00  Besluit onherroepelijk          10061280
# 4  2014-02-24 00:00:00+01:00  Besluit onherroepelijk          10061280
#
#               case:startDate case:requestComplete
# 0  2014-01-06 00:00:00+01:00                 TRUE
# 1  2014-01-06 00:00:00+01:00                 TRUE
# 2  2014-01-06 00:00:00+01:00                 TRUE
# 3  2014-01-06 00:00:00+01:00                 TRUE
# 4  2014-01-06 00:00:00+01:00                 TRUE

# %%
finalDf=dfAfterDrop.sort_values(by='time:timestamp')     #Sorting dataframe according to the timestamp.

# %%
pd.set_option('max_columns',None)
finalDf.isnull().sum()           #checking nulls if any.
# Out:
# action_code              47
# activityNameEN            0
# time:timestamp            0
# case:endDate            493
# case:last_phase           0
# case:concept:name         0
# case:startDate            0
# case:requestComplete      0
# dtype: int64

# %%
grouped= finalDf.groupby(finalDf['case:concept:name'])           #Grouped by cases.

# %%
temp= dfAfterDrop[['activityNameEN', 'case:concept:name']]      #Considering only 2 most important columns.
shrinkDf= temp.dropna()
gb = shrinkDf.groupby('case:concept:name')          #making groups respect to the each case.

len(gb)         #represent total number of cases with different event cycle.
# Out:
# 1051

# %% [markdown]
# # 2. N-gram model.

# %%
sequences=[]                       #List of sequences(events).
  
for i in gb.groups:
    a=gb.get_group(i)
    sequences.append(list(a['activityNameEN']))

# %%
ip= ['procedure change',
 'request complete',
 'send letter in progress',            #length 10.
 'procedure change',
 'article 34  WABO applies',
 'grounds for refusal',
 'ask stakeholders views',
 'suspension ground applicable',
 'coordination of application',
 'by law']

# %%
ipGram=[]
for i in range(0,len(ip)):
    ipGram.append(ip[i:len(ip)+1])
    
def mediator(a, b):
    a=data
    b= denometer

    dict1 = {item:a.count(item) for item in a}        #aggregate the same activities and give count.
    prob = {c: d / b for c, d in dict1.items()}     #dictionary of final probability.
    return prob

def createDataframe(ans):             #Function to create a dataframe.
    temp= list(ans.items())
    df=pd.DataFrame(temp[:10])
    df= df.sort_values([1,0], ascending=False)
    return df

def visualize(df):                   #to visualize the probabilites of each possible event.
    plt.title('N-grams')
    plt.figure(figsize=(12,6))
    
    plt.bar(x=df[0], height=df[1], edgecolor=['black'])
    plt.xticks(df[0], rotation=45)
    plt.xlabel('Activities', fontweight='bold', color = 'orange', fontsize='18')
    plt.ylabel('Probability', fontweight='bold', color = 'orange', fontsize='18')
    plt.savefig('a.png')

master=[]
def masterDataframe(ans):
    master.append(list(ans.values()))

# %%
m=0
n= len(ip)
denometer=0
data=[]
for k in range(0, len(ip)):                            #loop for n grams
    for i in range(0, len(sequences)):                 #looop for sequences 1051
        for j in range(0, len(sequences[i])):          #loop for inner activites(each case)
            if(ipGram[k] == sequences[i][m+j:n+j-k]):
                denometer+=1
                if((n+j+k)< len(sequences[i])):
                    data.append(sequences[i][n+j-k+1])
                    
    ans= mediator(data, denometer)
    denometer=0
    data=[]
    df= createDataframe(ans)
    visualize(df)
    masterDataframe(ans)

# %% [markdown]
# # 3. Final output.

# %%
final = pd.DataFrame(master,columns= list(ans.keys()),            #final dataframe
                 index=['10_Gram','9_Gram','8_Gram','7_Gram','6_Gram','5_Gram','4_Gram','3_Gram','2_Gram','1_Gram'])

# %%
final.head(10)
# Out:
#          no permit needed or only notification needed  \
# 10_Gram                                      0.179245
# 9_Gram                                       0.181818
# 8_Gram                                       0.112994
# 7_Gram                                       0.095745
# 6_Gram                                       0.092784
# 5_Gram                                       0.088816
# 4_Gram                                       0.087379
# 3_Gram                                       0.084375
# 2_Gram                                       0.083591
# 1_Gram                                       0.032143
#
#          create subcases completeness  phase advice known  submit decision  \
# 10_Gram                      0.056604            0.433962         0.018868
# 9_Gram                       0.054545            0.436364         0.018182
# 8_Gram                       0.045198            0.457627         0.011299
# 7_Gram                       0.053191            0.035461         0.436170
# 6_Gram                       0.051546            0.034364         0.436426
# 5_Gram                       0.049342            0.032895         0.421053
# 4_Gram                       0.048544            0.032362         0.414239
# 3_Gram                       0.046875            0.031250         0.409375
# 2_Gram                       0.046440            0.030960         0.405573
# 1_Gram                       0.017857            0.033333         0.159524
#
#          procedure change  OLO messaging active  updated plan received  \
# 10_Gram          0.018868              0.018868               0.028302
# 9_Gram           0.018182              0.018182               0.027273
# 8_Gram           0.033898              0.022599               0.028249
# 7_Gram           0.007092              0.003546               0.039007
# 6_Gram           0.017182              0.006873               0.003436
# 5_Gram           0.016447              0.006579               0.003289
# 4_Gram           0.019417              0.006472               0.003236
# 3_Gram           0.021875              0.006250               0.003125
# 2_Gram           0.021672              0.006192               0.003096
# 1_Gram           0.010714              0.002381               0.001190
#
#          assessment of content completed  MER present in supplement  \
# 10_Gram                         0.066038                   0.028302
# 9_Gram                          0.072727                   0.027273
# 8_Gram                          0.016949                   0.033898
# 7_Gram                          0.017730                   0.042553
# 6_Gram                          0.037801                   0.017182
# 5_Gram                          0.036184                   0.016447
# 4_Gram                          0.035599                   0.016181
# 3_Gram                          0.034375                   0.018750
# 2_Gram                          0.034056                   0.018576
# 1_Gram                          0.039286                   0.001190
#
#          receive additional information  phase application receptive  \
# 10_Gram                        0.056604                     0.018868
# 9_Gram                         0.054545                     0.018182
# 8_Gram                         0.039548                     0.016949
# 7_Gram                         0.053191                     0.007092
# 6_Gram                         0.041237                     0.051546
# 5_Gram                         0.039474                     0.049342
# 4_Gram                         0.038835                     0.048544
# 3_Gram                         0.037500                     0.046875
# 2_Gram                         0.037152                     0.046440
# 1_Gram                         0.007143                     0.014286
#
#          completed subcases content  \
# 10_Gram                    0.018868
# 9_Gram                     0.018182
# 8_Gram                     0.056497
# 7_Gram                     0.003546
# 6_Gram                     0.003436
# 5_Gram                     0.003289
# 4_Gram                     0.003236
# 3_Gram                     0.003125
# 2_Gram                     0.003096
# 1_Gram                     0.017857
#
#          send confirmation receipt additional data  grounds for refusal  \
# 10_Gram                                   0.009434             0.009434
# 9_Gram                                    0.009091             0.009091
# 8_Gram                                    0.022599             0.011299
# 7_Gram                                    0.042553             0.003546
# 6_Gram                                    0.041237             0.003436
# 5_Gram                                    0.042763             0.003289
# 4_Gram                                    0.003236             0.038835
# 3_Gram                                    0.003125             0.037500
# 2_Gram                                    0.003096             0.037152
# 1_Gram                                    0.002381             0.001190
#
#          create subcases content  creating environmental permit decision  \
# 10_Gram                 0.018868                                0.009434
# 9_Gram                  0.018182                                0.009091
# 8_Gram                  0.005650                                0.045198
# 7_Gram                  0.007092                                0.028369
# 6_Gram                  0.006873                                0.003436
# 5_Gram                  0.006579                                0.003289
# 4_Gram                  0.003236                                0.006472
# 3_Gram                  0.003125                                0.006250
# 2_Gram                  0.003096                                0.006192
# 1_Gram                  0.001190                                0.047619
#
#          request complete  start decision phase extension granted  \
# 10_Gram          0.009434                                     NaN
# 9_Gram           0.009091                                     NaN
# 8_Gram           0.011299                                0.011299
# 7_Gram           0.024823                                0.039007
# 6_Gram           0.027491                                0.024055
# 5_Gram           0.036184                                0.023026
# 4_Gram           0.003236                                0.038835
# 3_Gram           0.003125                                0.037500
# 2_Gram           0.003096                                0.040248
# 1_Gram           0.002381                                0.001190
#
#          set decision status  treat subcases completeness  \
# 10_Gram                  NaN                          NaN
# 9_Gram                   NaN                          NaN
# 8_Gram              0.005650                     0.005650
# 7_Gram              0.007092                     0.003546
# 6_Gram              0.037801                     0.006873
# 5_Gram              0.036184                     0.006579
# 4_Gram              0.022654                     0.035599
# 3_Gram              0.021875                     0.034375
# 2_Gram              0.021672                     0.034056
# 1_Gram              0.016667                     0.008333
#
#          treat subcases content   publish  \
# 10_Gram                     NaN       NaN
# 9_Gram                      NaN       NaN
# 8_Gram                 0.005650       NaN
# 7_Gram                 0.014184  0.007092
# 6_Gram                 0.003436  0.013746
# 5_Gram                 0.003289  0.023026
# 4_Gram                 0.006472  0.003236
# 3_Gram                 0.006250  0.003125
# 2_Gram                 0.006192  0.003096
# 1_Gram                 0.013095  0.002381
#
#          enter senddate decision environmental permit  \
# 10_Gram                                           NaN
# 9_Gram                                            NaN
# 8_Gram                                            NaN
# 7_Gram                                       0.003546
# 6_Gram                                       0.006873
# 5_Gram                                       0.003289
# 4_Gram                                       0.029126
# 3_Gram                                       0.046875
# 2_Gram                                       0.052632
# 1_Gram                                       0.001190
#
#          register objection and appeal periods  \
# 10_Gram                                    NaN
# 9_Gram                                     NaN
# 8_Gram                                     NaN
# 7_Gram                                0.007092
# 6_Gram                                0.003436
# 5_Gram                                0.013158
# 4_Gram                                0.003236
# 3_Gram                                0.003125
# 2_Gram                                0.003096
# 1_Gram                                0.001190
#
#          create draft environtmental permit  \
# 10_Gram                                 NaN
# 9_Gram                                  NaN
# 8_Gram                                  NaN
# 7_Gram                             0.007092
# 6_Gram                             0.006873
# 5_Gram                             0.006579
# 4_Gram                             0.012945
# 3_Gram                             0.012500
# 2_Gram                             0.012384
# 1_Gram                             0.001190
#
#          generating decision environmental permit  terminate on request  \
# 10_Gram                                       NaN                   NaN
# 9_Gram                                        NaN                   NaN
# 8_Gram                                        NaN                   NaN
# 7_Gram                                   0.003546              0.003546
# 6_Gram                                   0.006873              0.003436
# 5_Gram                                   0.003289              0.006579
# 4_Gram                                   0.006472              0.003236
# 3_Gram                                   0.006250              0.003125
# 2_Gram                                   0.006192              0.003096
# 1_Gram                                   0.001190              0.001190
#
#          subcases completeness completed  send confirmation receipt  \
# 10_Gram                              NaN                        NaN
# 9_Gram                               NaN                        NaN
# 8_Gram                               NaN                        NaN
# 7_Gram                          0.003546                        NaN
# 6_Gram                          0.003436                   0.003436
# 5_Gram                          0.006579                   0.003289
# 4_Gram                          0.006472                   0.006472
# 3_Gram                          0.006250                   0.006250
# 2_Gram                          0.006192                   0.006192
# 1_Gram                          0.005952                   0.003571
#
#          decision date prior to decision  register deadline  \
# 10_Gram                              NaN                NaN
# 9_Gram                               NaN                NaN
# 8_Gram                               NaN                NaN
# 7_Gram                               NaN                NaN
# 6_Gram                               NaN                NaN
# 5_Gram                          0.003289           0.003289
# 4_Gram                          0.003236           0.003236
# 3_Gram                          0.003125           0.003125
# 2_Gram                          0.003096           0.003096
# 1_Gram                          0.040476           0.001190
#
#          procedure change after completeness  resume completeness subcases  \
# 10_Gram                                  NaN                           NaN
# 9_Gram                                   NaN                           NaN
# 8_Gram                                   NaN                           NaN
# 7_Gram                                   NaN                           NaN
# 6_Gram                                   NaN                           NaN
# 5_Gram                                   NaN                           NaN
# 4_Gram                              0.003236                           NaN
# 3_Gram                              0.003125                           NaN
# 2_Gram                              0.003096                           NaN
# 1_Gram                              0.001190                      0.002381
#
#          phase additional information received  start WABOprocedure  \
# 10_Gram                                    NaN                  NaN
# 9_Gram                                     NaN                  NaN
# 8_Gram                                     NaN                  NaN
# 7_Gram                                     NaN                  NaN
# 6_Gram                                     NaN                  NaN
# 5_Gram                                     NaN                  NaN
# 4_Gram                                     NaN                  NaN
# 3_Gram                                     NaN                  NaN
# 2_Gram                                     NaN                  NaN
# 1_Gram                                 0.00119             0.002381
#
#          retrieve missing data  record date of decision environmental permit  \
# 10_Gram                    NaN                                           NaN
# 9_Gram                     NaN                                           NaN
# 8_Gram                     NaN                                           NaN
# 7_Gram                     NaN                                           NaN
# 6_Gram                     NaN                                           NaN
# 5_Gram                     NaN                                           NaN
# 4_Gram                     NaN                                           NaN
# 3_Gram                     NaN                                           NaN
# 2_Gram                     NaN                                           NaN
# 1_Gram                 0.00119                                       0.00119
#
#          forward to the competent authority
# 10_Gram                                 NaN
# 9_Gram                                  NaN
# 8_Gram                                  NaN
# 7_Gram                                  NaN
# 6_Gram                                  NaN
# 5_Gram                                  NaN
# 4_Gram                                  NaN
# 3_Gram                                  NaN
# 2_Gram                                  NaN
# 1_Gram                              0.00119
